# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mateus\OneDrive\Área de Trabalho\arquivos_csv\Clientes.csv", delimiter=",")
df.head()
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
# Filtrar somente o estado Mato Grosso
estado = df.loc[df["state"] == "Mato Grosso"]
estado.head()
# Out:
#     id           created_at first_name last_name                    email  \
# 3    3  2018-01-17 03:02:58    Daniela   Avelino      daniela@exemplo.com
# 12  12  2018-03-28 00:24:00      Carol   Barboza        carol@exemplo.com
# 15  15  2018-11-15 18:00:53  Stephanie   Barbosa    stephanie@usuario.com
# 66  66  2018-10-18 04:31:59  Stephanie     Abreu  stephanie@meu_email.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa     cibele@meu_email.com
#
#      cell_phone country        state                          street  number  \
# 3   9 4642-9486  Brasil  Mato Grosso                             NaN     NaN
# 12  9 8487-3501  Brasil  Mato Grosso    Rua 31 do Estado Mato Grosso     1.0
# 15  9 1446-3560  Brasil  Mato Grosso                             NaN     NaN
# 66  9 6466-2389  Brasil  Mato Grosso    Rua 19 do Estado Mato Grosso    53.0
# 98  9 4211-6968  Brasil  Mato Grosso  Praça 75 do Estado Mato Grosso    24.0
#
#     additionals
# 3           NaN
# 12  Conjunto 23
# ...

# %%
# Escolher vários estados
lista_estados = ["Rio de Janeiro", "Ceará", "Bahia", "Rondônia"]
estado2 = df.loc[df["state"].isin(lista_estados)]
estado2.head()
# Out:
#     id           created_at first_name last_name            email  \
# 4    4  2018-08-06 07:24:16    Romário  Teixeira              NaN
# 21  21  2018-02-21 15:35:55      Diego    Freire  diego@teste.com
# 24  24  2018-07-25 09:34:12       Jair   Barroso   jair@teste.com
# 32  32  2018-07-22 11:59:27        Ana    Campos    ana@teste.com
# 43  43  2018-01-07 07:54:22    Daniela      Lima              NaN
#
#      cell_phone country           state                      street  number  \
# 4   9 3093-6522  Brasil           Bahia    Praça 56 do Estado Bahia   191.0
# 21  9 6686-4094  Brasil           Bahia     Praça 4 do Estado Bahia   906.0
# 24  9 6679-6120  Brasil           Ceará      Rua 86 do Estado Ceará   770.0
# 32  9 1932-9841  Brasil           Bahia  Avenida 52 do Estado Bahia   402.0
# 43  9 1763-2584  Brasil  Rio de Janeiro                         NaN     NaN
#
#    additionals
# 4      Apto 12
# 21     Apto 20
# 24     Apto 21
# 32         NaN
# 43     Apto 20

# %%
# Substituindo os valores nulos
df["street"] = df["street"].fillna("Não Registrado")
df["number"] = df["street"].fillna("Sem Número")
df["additionals"] = df["street"].fillna("Sem Registro")

# %%
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
df["state"] = df["state"].replace("São Paulo", "SP")
df["state"] = df["state"].replace("Distrito Federal", "DF")
df["state"] = df["state"].replace("Acre", "AC")
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil                 AC
# ...

# %%
#Substituindo em forma de variável:
valor_original = "Paraná"
valor_novo = "PR"

df["state"] = df["state"].replace(valor_original, valor_novo)
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil                 AC
# ...
